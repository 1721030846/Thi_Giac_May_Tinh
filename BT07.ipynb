# %%
# !pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
# duong dan anh
my_path ='C:/Users/Admin/Desktop/Thi Giac May Tinh/img/acheron.png'
# doc anh va hien thi
im = Image.open(my_path)
# display(im)
plt.imshow(im)

# %%
# ve do thi co ban
x = [1, 2, 3, 4, 5]
y = [30, 25, 20, 10, 1]
plt.plot(x,y, color="blue")
plt.title("Bieu do suy")
plt.axis("off")
plt.show()

# %%
# ve tren hinh anh
# doc anh
x = [200, 600, 800, 1000, 1400]
y = [100, 200, 400, 600, 800]

plt.imshow(im)
plt.plot(x, y, 'bo--')
plt.show()
