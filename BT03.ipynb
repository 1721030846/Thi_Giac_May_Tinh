# %%
# import 
from PIL import Image
from imgtools import *

# %%
# Duong dan cua anh
my_path ='C:/Users/Admin/Desktop/Thi Giac May Tinh/img/acheron2.png'

# %%
# Doc anh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1918x1078>

# %%
print(img.size)
# Out:
# (1918, 1078)

# %%
# Thay doi kich thuoc
thumbnail_size = (100, 100)
img.thumbnail(thumbnail_size)
display(img)
# Task: luu anh xuong o dia
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=100x56>

# %%
# Thay doi kich thuoc anh
new_size = (800, 500)
new_image = img.resize(new_size)
display(new_image)
# task : luu anh xuong o dia
# Out:
# <PIL.Image.Image image mode=RGBA size=800x500>
