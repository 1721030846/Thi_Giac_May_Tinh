# %%
# Shift + Enter: run doan code, sau do them 1 dong moi

# %%
# Ctrl + Enter: chi run doan code

# %%
# Cai dat
# !pip install Pillow

# %%
# Import thu vien
from PIL import Image

# %%
# Thu muc chua anh
# Trong python dung dau / or \\
import os
print(os.getcwd()) # in thu muc hien tai
# Out:
# C:\Users\Admin\Desktop\Thi Giac May Tinh

# %%
dir = 'C:/Users/Admin/Desktop/Thi Giac May Tinh/img'

# %%
# Tao duong dan den anh
image_path = dir + '/acheron.png'
print(image_path)
# Out:
# C:/Users/Admin/Desktop/Thi Giac May Tinh/img/acheron.png

# %%
# Su dung  Image.open() de doc anh
imgacheron = Image.open(image_path)

# %%
# Hien thi anh
display(imgacheron)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1600x897>

# %%
# Dinh dang cua anh
print("Dinh dang anh: ", imgacheron.format)
# Out:
# Dinh dang anh:  PNG

# %%
# In ra size
print("Kich thuoc anh: ", imgacheron.size)
# Out:
# Kich thuoc anh:  (1600, 897)

# %%
# Chuyen doi anh thanh dinh dang moi
new_img_01_path = dir + "/new_01.PNG"
new_img_02_path = dir + "/new_02.PNG"
imgacheron.save(new_img_01_path)
imgacheron.save(new_img_02_path)

# %%
# Dong tap tin
imgacheron.close()
