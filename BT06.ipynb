# %%
# import 
from PIL import Image
from imgtools import *

# %%
# Duong dan cua anh
my_path ='C:/Users/Admin/Desktop/Thi Giac May Tinh/img/hsr.png'

# %%
# Doc anh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=892x663>

# %%
# chuyen tu anh RGB sang anh xam
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=892x663>

# %%
# phan anh thanh 3 tang mau khac nhau
red_band, green_band, blue_band =img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 # phan anh thanh 3 tang mau khac nhau
# ----> 2 red_band, green_band, blue_band =img.split()
#       3 display(red_band)
#       4 display(green_band)
#
# ValueError: too many values to unpack (expected 3)

# %%
merged_image = Image.merge("RGB", (green_band, blue_band, red_band))
display(merged_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 merged_image = Image.merge("RGB", (green_band, blue_band, red_band))
#       2 display(merged_image)
#
# NameError: name 'green_band' is not defined
